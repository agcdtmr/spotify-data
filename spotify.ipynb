# %% [markdown]
# ## Set Up Environment

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_style("white")

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv("./datasets/spotify_data.csv")

# %%
df
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0              0       0.01020         0.833       204600   0.434
# 1              1       0.19900         0.743       326933   0.359
# 2              2       0.03440         0.838       185707   0.412
# 3              3       0.60400         0.494       199413   0.338
# 4              4       0.18000         0.678       392893   0.561
# ...          ...           ...           ...          ...     ...
# 2012        2012       0.00106         0.584       274404   0.932
# 2013        2013       0.08770         0.894       182182   0.892
# 2014        2014       0.00857         0.637       207200   0.935
# 2015        2015       0.00164         0.557       185600   0.992
# 2016        2016       0.00281         0.446       204520   0.915
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0             0.021900    2    0.1650    -8.795     1       0.4310  150.062
# ...

# %%
# delete not needed column
df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
df
# Out:
#       acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0          0.01020         0.833       204600   0.434          0.021900    2
# 1          0.19900         0.743       326933   0.359          0.006110    1
# 2          0.03440         0.838       185707   0.412          0.000234    2
# 3          0.60400         0.494       199413   0.338          0.510000    5
# 4          0.18000         0.678       392893   0.561          0.512000    5
# ...            ...           ...          ...     ...               ...  ...
# 2012       0.00106         0.584       274404   0.932          0.002690    1
# 2013       0.08770         0.894       182182   0.892          0.001670    1
# 2014       0.00857         0.637       207200   0.935          0.003990    0
# 2015       0.00164         0.557       185600   0.992          0.677000    1
# 2016       0.00281         0.446       204520   0.915          0.000039    9
#
# ...

# %%
df.head()
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0        0.0102         0.833       204600   0.434          0.021900    2
# 1        0.1990         0.743       326933   0.359          0.006110    1
# 2        0.0344         0.838       185707   0.412          0.000234    2
# 3        0.6040         0.494       199413   0.338          0.510000    5
# 4        0.1800         0.678       392893   0.561          0.512000    5
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0    0.1650    -8.795     1       0.4310  150.062             4.0    0.286
# 1    0.1370   -10.401     1       0.0794  160.083             4.0    0.588
# 2    0.1590    -7.148     1       0.2890   75.044             4.0    0.173
# 3    0.0922   -15.236     1       0.0261   86.468             4.0    0.230
# 4    0.4390   -11.648     0       0.0694  174.004             4.0    0.904
#
#    target      song_title            artist
# ...

# %% [markdown]
# ## Data Cleaning

# %%
df.isna().sum()
# Out:
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# target              0
# song_title          0
# artist              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2017 entries, 0 to 2016
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   acousticness      2017 non-null   float64
#  1   danceability      2017 non-null   float64
#  2   duration_ms       2017 non-null   int64
#  3   energy            2017 non-null   float64
#  4   instrumentalness  2017 non-null   float64
#  5   key               2017 non-null   int64
#  6   liveness          2017 non-null   float64
#  7   loudness          2017 non-null   float64
#  8   mode              2017 non-null   int64
#  9   speechiness       2017 non-null   float64
#  10  tempo             2017 non-null   float64
#  11  time_signature    2017 non-null   float64
#  12  valence           2017 non-null   float64
#  13  target            2017 non-null   int64
#  14  song_title        2017 non-null   object
#  15  artist            2017 non-null   object
# ...

# %%
df.shape
# Out:
# (2017, 16)

# %%
df.columns
# Out:
# Index(['acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence', 'target',
#        'song_title', 'artist'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 16

# %%
df.describe()
# Out:
#        acousticness  danceability   duration_ms       energy  \
# count   2017.000000   2017.000000  2.017000e+03  2017.000000
# mean       0.187590      0.618422  2.463062e+05     0.681577
# std        0.259989      0.161029  8.198181e+04     0.210273
# min        0.000003      0.122000  1.604200e+04     0.014800
# 25%        0.009630      0.514000  2.000150e+05     0.563000
# 50%        0.063300      0.631000  2.292610e+05     0.715000
# 75%        0.265000      0.738000  2.703330e+05     0.846000
# max        0.995000      0.984000  1.004627e+06     0.998000
#
#        instrumentalness          key     liveness     loudness         mode  \
# count       2017.000000  2017.000000  2017.000000  2017.000000  2017.000000
# mean           0.133286     5.342588     0.190844    -7.085624     0.612295
# std            0.273162     3.648240     0.155453     3.761684     0.487347
# min            0.000000     0.000000     0.018800   -33.097000     0.000000
# ...

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### Top 5 most popular artists

# %%
# better alternative
# top_five_artist=df["artist"].groupby(df["artist"]).count().nlargest(5)

top_five_artists = df.groupby("artist").count().sort_values(by="song_title", ascending=False)["song_title"][:5]
top_five_artists
# Out:
# artist
# Drake              16
# Rick Ross          13
# Disclosure         12
# Backstreet Boys    10
# WALK THE MOON      10
# Name: song_title, dtype: int64

# %%
top_five_artists.plot.barh()
# plt.show()
# Out:
# <AxesSubplot:ylabel='artist'>

# %% [markdown]
# ### Top 5 loudest tracks

# %%
# ascending is True becacause Values typically range between -60 and 0 db (-60 the highest)
top_five_loudest = df[["loudness", "song_title"]].sort_values(by="loudness", ascending=True)[:5]

# %%
top_five_loudest
# Out:
#       loudness                                         song_title
# 1594   -33.097            Lyric Pieces, Book I Op. 12: I. Arietta
# 1596   -31.367            8 Fantasiestücke, Op.12 : 1. Des Abends
# 1598   -31.082  Piano Quartet in E flat, Op.47: 3. Andante can...
# 1531   -30.447          I Was So Young, and You Were So Beautiful
# 1549   -29.460                                            Eleanor

# %%
plt.figure(figsize=(12, 7))
sns.barplot(x="loudness", y="song_title", data=top_five_loudest)
plt.title("Top 5 loudest tracks")
plt.show()

# %% [markdown]
# ### Artist with the most danceability song

# %%
# A value of 0.0 is least danceable and 1.0 is most danceable.

top_five_artists_danceable_songs = df[["danceability", "song_title", "artist"]].sort_values(by="danceability", ascending=False)[:5]
top_five_artists_danceable_songs
# Out:
#       danceability              song_title             artist
# 1433         0.984  Flashwind - Radio Edit       Ben Remember
# 1901         0.967                SexyBack  Justin Timberlake
# 604          0.962       Check Me Out Like          Blaqstarr
# 32           0.959             Best Friend         Young Thug
# 1957         0.959            Ice Ice Baby        Vanilla Ice

# %%
plt.figure(figsize=(12, 7))
sns.barplot(x="danceability", y="artist", data=top_five_artists_danceable_songs)

plt.title("Artist With The Most Danceability Song")
plt.show()

# %% [markdown]
# ### Top 10 instrumental tracks

# %%
# Predicts whether a track contains no vocals. "Ooh" and "aah" 
# sounds are treated as instrumental in this context. Rap or 
# spoken word tracks are clearly "vocal". The closer the instrumentalness 
# value is to 1.0, the greater likelihood the track contains no vocal 
# content. Values above 0.5 are intended to represent instrumental tracks,
# but confidence is higher as the value approaches 1.0.

top_ten_instrumental_tracks = df[["instrumentalness", "song_title", "artist"]].sort_values(by="instrumentalness", ascending=False)[:10]
top_ten_instrumental_tracks
# Out:
#       instrumentalness                            song_title  \
# 1313             0.976                       Senseless Order
# 271              0.968  So Destroyed (channeling Rage Peace)
# 1575             0.964             A Hundred Dreams from Now
# 1619             0.958                                 Raven
# 725              0.957                     Strandbar (disko)
# 1546             0.956                        Almas vaggvisa
# 1322             0.955                            Pitchblack
# 1349             0.954                       Prismatic Abyss
# 1661             0.954                               Yebisah
# 121              0.952                        Chasing Heaven
#
#                         artist
# 1313        Signs of the Swarm
# 271                Prince Rama
# 1575                Ray Bryant
# 1619             John Dahlbäck
# 725                 Todd Terje
# 1546         Jan Lundgren Trio
# 1322  Walking Dead On Broadway
# 1349           Aversions Crown
# ...

# %%
# without plt.show()

plt.figure(figsize=(12, 7))
plt.pie(x="instrumentalness", data=top_ten_instrumental_tracks, autopct='%1.2f%%', labels= top_ten_instrumental_tracks.song_title)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f8c2a805d90>,
# ...
#  [Text(1.0442990117584923, 0.34560030966455557, 'Senseless Order'),
#   Text(0.6343227492098891, 0.8986849558297993, 'So Destroyed (channeling Rage Peace)'),
#   Text(-0.01980992482998372, 1.0998216068427782, 'A Hundred Dreams from Now'),
#   Text(-0.6634052773678965, 0.8774357172810009, 'Raven'),
#   Text(-1.0520510218123973, 0.32122989820919706, 'Strandbar (disko)'),
#   Text(-1.040620350628522, -0.3565238924080292, 'Almas vaggvisa'),
#   Text(-0.6346169771658708, -0.8984772074420435, 'Pitchblack'),
#   Text(0.011166025522058866, -1.0999433257554867, 'Prismatic Abyss'),
#   Text(0.6524360456983562, -0.8856224964811433, 'Yebisah'),
#   Text(1.0469827853487086, -0.33738264208974933, 'Chasing Heaven')],
#  [Text(0.5696176427773593, 0.1885092598170303, '10.17%'),
#   Text(0.3459942268417577, 0.4901917940889814, '10.09%'),
#   Text(-0.010805413543627481, 0.5999026946415154, '10.05%'),
# ...

# %%
# with plt.show()

plt.figure(figsize=(12, 7))
plt.pie(x="instrumentalness", data=top_ten_instrumental_tracks, autopct='%1.2f%%', labels= top_ten_instrumental_tracks.song_title)
plt.show()

# %% [markdown]
# ### Multiple feature plots

# %%
df.columns
# Out:
# Index(['acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence', 'target',
#        'song_title', 'artist'],
#       dtype='object')

# %%
interested_feature_columns = ["tempo", "loudness", "acousticness", "danceability", "duration_ms",
                              "energy", "instrumentalness", "liveness", "speechiness", "valence"]

# %%
for feature_column in interested_feature_columns:
    positive_data = df[df["target"] == 1][feature_column]
    negative_data = df[df["target"] == 0][feature_column]
    
    plt.figure(figsize=(12, 7))
    
    sns.distplot(positive_data, bins=30, label="Positive", color="pink")
    sns.distplot(negative_data, bins=30, label="Negative", color="purple")
    
    plt.legend(loc="upper right")
    plt.title(f"Positive and Negative Historgram Plot for {feature_column}")
    plt.show()
# Out:
# /Applications/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Applications/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ## Analysis

# %% [markdown]
# The tempo between 130-140 are most like and if a track is too slow or or too fast, the likes decreases
#
# The loudliness -20 to -7 seems the listener tends to listen to, but when the music is louder or extremely loud greater than -7 the listener of that track decreases, the dislikes increases
#
# The acoustic
#
# The danceability
#
# duration_ms
# energy
# instrumentalness
# liveness
# speechiness
# valence
